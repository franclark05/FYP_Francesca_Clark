# %% [markdown]
# # Shuttle Training FYP - YOLOv5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17822, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 17822 (delta 16), reused 6 (delta 6), pack-reused 17794 (from 2)
# Receiving objects: 100% (17822/17822), 16.96 MiB | 18.42 MiB/s, done.
# Resolving deltas: 100% (12144/12144), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 17.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# !cp -r /content/drive/MyDrive/dataset_shuttle /content/

# %%
# %%writefile data.yaml
# train: /content/drive/MyDrive/dataset_shuttle/images/train
# val: /content/drive/MyDrive/dataset_shuttle/images/val
#
# nc: 1
# names: ['Shuttle']
# Out:
# Writing data.yaml

# %%
# !python train.py \
--img 1280 \
--batch 16 \
--epochs 100 \
--data data.yaml \
--weights yolov5s.pt \
--project /content/drive/MyDrive/runs_fyp \
--name shuttle_model \
--save-period 10
# Out:
# Streaming output truncated to the last 5000 lines.
#       38/99        13G    0.01944   0.003734          0         29       1280:  47% 80/170 [02:19<02:22,  1.59s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/99        13G    0.01947    0.00373          0         32       1280:  48% 81/170 [02:21<02:31,  1.70s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/99        13G    0.01952   0.003728          0         24       1280:  48% 82/170 [02:22<02:07,  1.44s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# WHEN INTERRUPTED

# %%
# !python train.py \
--resume /content/drive/MyDrive/runs_fyp/shuttle_model/weights/last.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#       60/99        13G    0.01577   0.003105          0         26       1280:  44% 74/170 [02:11<02:33,  1.60s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       60/99        13G    0.01577   0.003101          0         24       1280:  44% 75/170 [02:13<02:53,  1.83s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       60/99        13G    0.01576   0.003098          0         26       1280:  45% 76/170 [02:14<02:22,  1.52s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python train.py \
--resume /content/drive/MyDrive/runs_fyp/shuttle_model/weights/last.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#       85/99        13G    0.01324   0.002771          0         25       1280:  33% 56/170 [01:38<03:28,  1.83s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       85/99        13G    0.01321   0.002771          0         34       1280:  34% 57/170 [01:40<03:51,  2.05s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       85/99        13G    0.01314   0.002779          0         30       1280:  34% 58/170 [01:41<03:14,  1.73s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python val.py \
--weights /content/drive/MyDrive/runs_fyp/shuttle_model/weights/best.pt \
--data data.yaml \
--img 960
# Out:
# val: data=data.yaml, weights=['/content/drive/MyDrive/runs_fyp/shuttle_model/weights/best.pt'], batch_size=32, imgsz=960, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-460-g3fb11111 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset_shuttle/labels/val.cache... 615 images, 1 backgrounds, 0 corrupt: 100% 615/615 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:45<00:00,  2.29s/it]
#                    all        615        615      0.984      0.992      0.995      0.764
# ...

# %%
# !python detect.py \
--weights /content/drive/MyDrive/runs_fyp/shuttle_model/weights/best.pt \
--source /content/drive/MyDrive/dataset_shuttle/images/val \
--img 960 \
--conf 0.25 \
--project /content/drive/MyDrive/predictions_shuttle \
--name val_visualisation \
--exist-ok
# Out:
# detect: weights=['/content/drive/MyDrive/runs_fyp/shuttle_model/weights/best.pt'], source=/content/drive/MyDrive/dataset_shuttle/images/val, data=data/coco128.yaml, imgsz=[960, 960], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/predictions_shuttle, name=val_visualisation, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-460-g3fb11111 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/615 /content/drive/MyDrive/dataset_shuttle/images/val/P1_foot_on_line_s28_f028557.jpg: 544x960 1 Shuttle, 33.7ms
# ...
